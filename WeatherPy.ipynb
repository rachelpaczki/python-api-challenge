# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 594

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url =  url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | aasiaat
# Processing Record 2 of Set 1 | jamestown
# Processing Record 3 of Set 1 | ocher
# Processing Record 4 of Set 1 | reyes
# Processing Record 5 of Set 1 | atherton
# Processing Record 6 of Set 1 | dakhla
# Processing Record 7 of Set 1 | severo-yeniseyskiy
# Processing Record 8 of Set 1 | susuman
# Processing Record 9 of Set 1 | kodiak
# Processing Record 10 of Set 1 | albany
# Processing Record 11 of Set 1 | papatowai
# Processing Record 12 of Set 1 | dong ha
# Processing Record 13 of Set 1 | codrington
# Processing Record 14 of Set 1 | puerto natales
# Processing Record 15 of Set 1 | grytviken
# Processing Record 16 of Set 1 | dauphin
# Processing Record 17 of Set 1 | ta'izz
# Processing Record 18 of Set 1 | waitangi
# Processing Record 19 of Set 1 | tabor
# Processing Record 20 of Set 1 | port mathurin
# Processing Record 21 of Set 1 | figuig (centre)
# Processing Record 22 of Set 1 | raduzhnyy
# Processing Record 23 of Set 1 | dolinsk
# Processing Record 24 of Set 1 | pontes e lacerda
# Processing Record 25 of Set 1 | san patricio
# Processing Record 26 of Set 1 | talcahuano
# Processing Record 27 of Set 1 | port-aux-francais
# Processing Record 28 of Set 1 | lompoc
# Processing Record 29 of Set 1 | ushuaia
# Processing Record 30 of Set 1 | flying fish cove
# Processing Record 31 of Set 1 | punta arenas
# Processing Record 32 of Set 1 | anloga
# Processing Record 33 of Set 1 | sinabang
# Processing Record 34 of Set 1 | bilibino
# Processing Record 35 of Set 1 | adamstown
# Processing Record 36 of Set 1 | mount isa
# Processing Record 37 of Set 1 | margaret river
# Processing Record 38 of Set 1 | blackmans bay
# Processing Record 39 of Set 1 | megion
# Processing Record 40 of Set 1 | hawaiian paradise park
# Processing Record 41 of Set 1 | tarnow
# Processing Record 42 of Set 1 | abocho
# Processing Record 43 of Set 1 | smithers
# Processing Record 44 of Set 1 | vernon
# Processing Record 45 of Set 1 | stanley
# Processing Record 46 of Set 1 | tiksi
# Processing Record 47 of Set 1 | brasilia
# Processing Record 48 of Set 1 | yauya
# Processing Record 49 of Set 1 | hermanus
# Processing Record 50 of Set 1 | lebu
# Processing Record 0 of Set 2 | benguela
# Processing Record 1 of Set 2 | puerto colombia
# Processing Record 2 of Set 2 | lazaro cardenas
# Processing Record 3 of Set 2 | vicente guerrero
# Processing Record 4 of Set 2 | rio grande
# Processing Record 5 of Set 2 | wailua homesteads
# Processing Record 6 of Set 2 | itamaraca
# Processing Record 7 of Set 2 | prince rupert
# Processing Record 8 of Set 2 | rudnichnyy
# Processing Record 9 of Set 2 | sitka
# Processing Record 10 of Set 2 | ust'-kut
# Processing Record 11 of Set 2 | brookings
# Processing Record 12 of Set 2 | bredasdorp
# Processing Record 13 of Set 2 | yerofey pavlovich
# Processing Record 14 of Set 2 | viitasaari
# Processing Record 15 of Set 2 | bethel
# Processing Record 16 of Set 2 | el granada
# Processing Record 17 of Set 2 | coquimbo
# Processing Record 18 of Set 2 | longyearbyen
# Processing Record 19 of Set 2 | edinburgh of the seven seas
# Processing Record 20 of Set 2 | kayangel
# Processing Record 21 of Set 2 | cartagena
# Processing Record 22 of Set 2 | mingora
# Processing Record 23 of Set 2 | aitape
# Processing Record 24 of Set 2 | ansalta
# Processing Record 25 of Set 2 | haiku-pauwela
# Processing Record 26 of Set 2 | tateyama
# Processing Record 27 of Set 2 | pisco
# Processing Record 28 of Set 2 | ribeira grande
# Processing Record 29 of Set 2 | yellowknife
# Processing Record 30 of Set 2 | cambria
# Processing Record 31 of Set 2 | safotu
# Processing Record 32 of Set 2 | hoogerheide
# Processing Record 33 of Set 2 | al kharj
# Processing Record 34 of Set 2 | sake
# Processing Record 35 of Set 2 | ketchikan
# Processing Record 36 of Set 2 | damavand
# Processing Record 37 of Set 2 | pangody
# Processing Record 38 of Set 2 | asmar
# Processing Record 39 of Set 2 | qaqortoq
# Processing Record 40 of Set 2 | afaahiti
# Processing Record 41 of Set 2 | kas
# Processing Record 42 of Set 2 | olonkinbyen
# Processing Record 43 of Set 2 | crane
# Processing Record 44 of Set 2 | atafu village
# Processing Record 45 of Set 2 | mbanza-ngungu
# Processing Record 46 of Set 2 | fort st. john
# Processing Record 47 of Set 2 | nadi
# Processing Record 48 of Set 2 | carnarvon
# Processing Record 49 of Set 2 | al marsa
# Processing Record 0 of Set 3 | mahibadhoo
# Processing Record 1 of Set 3 | burley
# Processing Record 2 of Set 3 | belmonte
# Processing Record 3 of Set 3 | isafjordur
# Processing Record 4 of Set 3 | anadyr
# Processing Record 5 of Set 3 | vaskelovo
# Processing Record 6 of Set 3 | whyalla stuart
# City not found. Skipping...
# Processing Record 7 of Set 3 | ancud
# Processing Record 8 of Set 3 | mokhsogollokh
# Processing Record 9 of Set 3 | yreka
# Processing Record 10 of Set 3 | dar chioukh
# Processing Record 11 of Set 3 | acapulco de juarez
# Processing Record 12 of Set 3 | kuala belait
# Processing Record 13 of Set 3 | aral
# Processing Record 14 of Set 3 | rengasdengklok
# Processing Record 15 of Set 3 | petropavlovsk-kamchatsky
# Processing Record 16 of Set 3 | invercargill
# Processing Record 17 of Set 3 | cururupu
# Processing Record 18 of Set 3 | hithadhoo
# Processing Record 19 of Set 3 | duba
# Processing Record 20 of Set 3 | broome
# Processing Record 21 of Set 3 | badger
# Processing Record 22 of Set 3 | colonia
# Processing Record 23 of Set 3 | sao jose de ribamar
# Processing Record 24 of Set 3 | touros
# Processing Record 25 of Set 3 | cabedelo
# Processing Record 26 of Set 3 | puerto ayora
# Processing Record 27 of Set 3 | olyokminsk
# Processing Record 28 of Set 3 | hayma'
# City not found. Skipping...
# Processing Record 29 of Set 3 | pundong
# Processing Record 30 of Set 3 | cable beach
# City not found. Skipping...
# Processing Record 31 of Set 3 | lake city
# Processing Record 32 of Set 3 | muisne
# Processing Record 33 of Set 3 | port elizabeth
# Processing Record 34 of Set 3 | sparti
# Processing Record 35 of Set 3 | cacador
# Processing Record 36 of Set 3 | tobi village
# City not found. Skipping...
# Processing Record 37 of Set 3 | visby
# Processing Record 38 of Set 3 | lata
# Processing Record 39 of Set 3 | enewetak
# Processing Record 40 of Set 3 | happy valley-goose bay
# Processing Record 41 of Set 3 | tazacorte
# Processing Record 42 of Set 3 | avarua
# Processing Record 43 of Set 3 | cidreira
# Processing Record 44 of Set 3 | ust-nera
# Processing Record 45 of Set 3 | ilulissat
# Processing Record 46 of Set 3 | ngereklmadel
# Processing Record 47 of Set 3 | chakulia
# Processing Record 48 of Set 3 | wewak
# Processing Record 49 of Set 3 | cadale
# Processing Record 0 of Set 4 | polevskoy
# Processing Record 1 of Set 4 | forster
# Processing Record 2 of Set 4 | mount gambier
# Processing Record 3 of Set 4 | geraldton
# Processing Record 4 of Set 4 | fuglafjordur
# Processing Record 5 of Set 4 | khairagarh
# Processing Record 6 of Set 4 | west island
# Processing Record 7 of Set 4 | kapuskasing
# Processing Record 8 of Set 4 | constantia
# Processing Record 9 of Set 4 | ras gharib
# City not found. Skipping...
# Processing Record 10 of Set 4 | cabo san lucas
# Processing Record 11 of Set 4 | el tigre
# Processing Record 12 of Set 4 | labrador city
# Processing Record 13 of Set 4 | nagqu
# Processing Record 14 of Set 4 | ta`u
# Processing Record 15 of Set 4 | fortuna
# Processing Record 16 of Set 4 | kerikeri
# Processing Record 17 of Set 4 | devinuwara
# City not found. Skipping...
# Processing Record 18 of Set 4 | talnakh
# Processing Record 19 of Set 4 | namdrik
# Processing Record 20 of Set 4 | choibalsan
# Processing Record 21 of Set 4 | turpan
# Processing Record 22 of Set 4 | iskateley
# Processing Record 23 of Set 4 | chonchi
# Processing Record 24 of Set 4 | greeley
# Processing Record 25 of Set 4 | yebaishou
# Processing Record 26 of Set 4 | hammerfest
# Processing Record 27 of Set 4 | luderitz
# Processing Record 28 of Set 4 | whitehorse
# Processing Record 29 of Set 4 | hongch'on
# Processing Record 30 of Set 4 | kalmunai
# Processing Record 31 of Set 4 | ujae
# Processing Record 32 of Set 4 | tura
# Processing Record 33 of Set 4 | altai
# Processing Record 34 of Set 4 | nogliki
# Processing Record 35 of Set 4 | vorgashor
# Processing Record 36 of Set 4 | mil'kovo
# Processing Record 37 of Set 4 | pont rouge
# Processing Record 38 of Set 4 | iqaluit
# Processing Record 39 of Set 4 | tamanrasset
# Processing Record 40 of Set 4 | naberera
# Processing Record 41 of Set 4 | minas de marcona
# Processing Record 42 of Set 4 | taiohae
# City not found. Skipping...
# Processing Record 43 of Set 4 | portland
# Processing Record 44 of Set 4 | trairi
# Processing Record 45 of Set 4 | skanor med falsterbo
# Processing Record 46 of Set 4 | el sauzal de rodriguez
# Processing Record 47 of Set 4 | recani
# Processing Record 48 of Set 4 | kataragama
# City not found. Skipping...
# Processing Record 49 of Set 4 | island harbour
# Processing Record 0 of Set 5 | alghero
# Processing Record 1 of Set 5 | arar
# Processing Record 2 of Set 5 | andovoranto
# Processing Record 3 of Set 5 | partur
# Processing Record 4 of Set 5 | lihue
# Processing Record 5 of Set 5 | amursk
# Processing Record 6 of Set 5 | weno
# Processing Record 7 of Set 5 | holualoa
# Processing Record 8 of Set 5 | amahai
# Processing Record 9 of Set 5 | badiyah
# Processing Record 10 of Set 5 | sirte
# Processing Record 11 of Set 5 | brisas de zicatela
# Processing Record 12 of Set 5 | odacho-oda
# Processing Record 13 of Set 5 | saipan
# Processing Record 14 of Set 5 | college
# Processing Record 15 of Set 5 | mitsamiouli
# Processing Record 16 of Set 5 | zinjibar
# Processing Record 17 of Set 5 | mogocha
# Processing Record 18 of Set 5 | nova vicosa
# Processing Record 19 of Set 5 | hauterive
# Processing Record 20 of Set 5 | kaka
# Processing Record 21 of Set 5 | utrik
# Processing Record 22 of Set 5 | hamilton
# Processing Record 23 of Set 5 | nouadhibou
# Processing Record 24 of Set 5 | tsiombe
# Processing Record 25 of Set 5 | kurumkan
# Processing Record 26 of Set 5 | shahrisabz
# Processing Record 27 of Set 5 | puerto san carlos
# City not found. Skipping...
# Processing Record 28 of Set 5 | mahdia
# Processing Record 29 of Set 5 | klyuchi
# Processing Record 30 of Set 5 | saiha
# Processing Record 31 of Set 5 | sandnessjoen
# Processing Record 32 of Set 5 | pascagoula
# Processing Record 33 of Set 5 | zheleznogorsk-ilimskiy
# Processing Record 34 of Set 5 | kijang
# Processing Record 35 of Set 5 | colby
# Processing Record 36 of Set 5 | chiili
# City not found. Skipping...
# Processing Record 37 of Set 5 | aberystwyth
# Processing Record 38 of Set 5 | ceerigaabo
# Processing Record 39 of Set 5 | tazovsky
# Processing Record 40 of Set 5 | saldanha
# Processing Record 41 of Set 5 | san julian
# Processing Record 42 of Set 5 | kununurra
# Processing Record 43 of Set 5 | ausa
# Processing Record 44 of Set 5 | retreat
# Processing Record 45 of Set 5 | liwale
# Processing Record 46 of Set 5 | dryden
# Processing Record 47 of Set 5 | mastic beach
# Processing Record 48 of Set 5 | corner brook
# Processing Record 49 of Set 5 | rye
# Processing Record 0 of Set 6 | panaba
# Processing Record 1 of Set 6 | aleksandrovsk
# Processing Record 2 of Set 6 | kangding
# Processing Record 3 of Set 6 | okha
# Processing Record 4 of Set 6 | pagar alam
# Processing Record 5 of Set 6 | hirara
# Processing Record 6 of Set 6 | mabaruma
# Processing Record 7 of Set 6 | tchintabaraden
# Processing Record 8 of Set 6 | la nucia
# Processing Record 9 of Set 6 | marsh harbour
# Processing Record 10 of Set 6 | ubari
# Processing Record 11 of Set 6 | cockburn town
# Processing Record 12 of Set 6 | rundu
# Processing Record 13 of Set 6 | itoman
# Processing Record 14 of Set 6 | zapadnaya dvina
# Processing Record 15 of Set 6 | kristiansund
# Processing Record 16 of Set 6 | shiguai
# Processing Record 17 of Set 6 | georgetown
# Processing Record 18 of Set 6 | paragominas
# Processing Record 19 of Set 6 | buka
# Processing Record 20 of Set 6 | safi
# Processing Record 21 of Set 6 | emerald
# Processing Record 22 of Set 6 | khalkhal
# Processing Record 23 of Set 6 | chilca
# Processing Record 24 of Set 6 | asaita
# Processing Record 25 of Set 6 | east london
# Processing Record 26 of Set 6 | magistral'nyy
# Processing Record 27 of Set 6 | vadso
# Processing Record 28 of Set 6 | kidal
# Processing Record 29 of Set 6 | howard springs
# Processing Record 30 of Set 6 | vega de alatorre
# Processing Record 31 of Set 6 | st. john's
# Processing Record 32 of Set 6 | turabah
# Processing Record 33 of Set 6 | pacific grove
# Processing Record 34 of Set 6 | asau
# Processing Record 35 of Set 6 | mount vernon
# Processing Record 36 of Set 6 | contamana
# Processing Record 37 of Set 6 | itaituba
# Processing Record 38 of Set 6 | quelimane
# Processing Record 39 of Set 6 | bcharre
# Processing Record 40 of Set 6 | onega
# Processing Record 41 of Set 6 | manghit
# Processing Record 42 of Set 6 | panama city beach
# Processing Record 43 of Set 6 | mogadishu
# Processing Record 44 of Set 6 | usogorsk
# Processing Record 45 of Set 6 | gorontalo
# Processing Record 46 of Set 6 | bitkine
# Processing Record 47 of Set 6 | villa berthet
# Processing Record 48 of Set 6 | arteche
# Processing Record 49 of Set 6 | changtu
# Processing Record 0 of Set 7 | fuvahmulah
# City not found. Skipping...
# Processing Record 1 of Set 7 | tralee
# Processing Record 2 of Set 7 | cedeira
# Processing Record 3 of Set 7 | nuuk
# Processing Record 4 of Set 7 | peace river
# Processing Record 5 of Set 7 | mukalla
# Processing Record 6 of Set 7 | nova sintra
# Processing Record 7 of Set 7 | thompson
# Processing Record 8 of Set 7 | hardoi
# Processing Record 9 of Set 7 | yarovoye
# Processing Record 10 of Set 7 | saint-paul
# Processing Record 11 of Set 7 | oranjemund
# Processing Record 12 of Set 7 | teteven
# Processing Record 13 of Set 7 | emporia
# Processing Record 14 of Set 7 | yasugicho
# Processing Record 15 of Set 7 | callao
# Processing Record 16 of Set 7 | menomonie
# Processing Record 17 of Set 7 | farasan
# Processing Record 18 of Set 7 | chu
# Processing Record 19 of Set 7 | keflavik
# Processing Record 20 of Set 7 | markaz-e hukumat-e darweshan
# Processing Record 21 of Set 7 | walvis bay
# Processing Record 22 of Set 7 | moshi
# Processing Record 23 of Set 7 | puerto deseado
# Processing Record 24 of Set 7 | santa rosa del sur
# Processing Record 25 of Set 7 | brosteni
# Processing Record 26 of Set 7 | rzhanitsa
# Processing Record 27 of Set 7 | oleshky
# Processing Record 28 of Set 7 | sebdou
# Processing Record 29 of Set 7 | mahabe
# City not found. Skipping...
# Processing Record 30 of Set 7 | colesberg
# Processing Record 31 of Set 7 | punta cana
# Processing Record 32 of Set 7 | mers el kebir
# Processing Record 33 of Set 7 | port lincoln
# Processing Record 34 of Set 7 | carolina beach
# Processing Record 35 of Set 7 | namibe
# Processing Record 36 of Set 7 | singleton
# Processing Record 37 of Set 7 | remire-montjoly
# Processing Record 38 of Set 7 | ottawa
# Processing Record 39 of Set 7 | le coteau
# Processing Record 40 of Set 7 | rio rancho
# Processing Record 41 of Set 7 | al bardiyah
# Processing Record 42 of Set 7 | port antonio
# Processing Record 43 of Set 7 | fale old settlement
# Processing Record 44 of Set 7 | alofi
# Processing Record 45 of Set 7 | sopo
# Processing Record 46 of Set 7 | kaa-khem
# Processing Record 47 of Set 7 | khandyga
# Processing Record 48 of Set 7 | indianola
# Processing Record 49 of Set 7 | whangarei
# Processing Record 0 of Set 8 | gurzuf
# Processing Record 1 of Set 8 | zhangye
# Processing Record 2 of Set 8 | laguna
# Processing Record 3 of Set 8 | grand falls-windsor
# Processing Record 4 of Set 8 | faya-largeau
# Processing Record 5 of Set 8 | salekhard
# Processing Record 6 of Set 8 | klaksvik
# Processing Record 7 of Set 8 | tacna
# Processing Record 8 of Set 8 | patong
# Processing Record 9 of Set 8 | auxerre
# Processing Record 10 of Set 8 | mokhotlong
# Processing Record 11 of Set 8 | mana
# Processing Record 12 of Set 8 | valdivia
# Processing Record 13 of Set 8 | tolanaro
# Processing Record 14 of Set 8 | sisimiut
# Processing Record 15 of Set 8 | rusape
# Processing Record 16 of Set 8 | port blair
# Processing Record 17 of Set 8 | nyurba
# Processing Record 18 of Set 8 | ceeldheer
# Processing Record 19 of Set 8 | dawson creek
# Processing Record 20 of Set 8 | elmendorf air force base
# City not found. Skipping...
# Processing Record 21 of Set 8 | nar'yan-mar
# Processing Record 22 of Set 8 | stephenville
# Processing Record 23 of Set 8 | djenne
# Processing Record 24 of Set 8 | manadhoo
# Processing Record 25 of Set 8 | dalbandin
# Processing Record 26 of Set 8 | vargem grande
# Processing Record 27 of Set 8 | orchard homes
# Processing Record 28 of Set 8 | ouellah
# City not found. Skipping...
# Processing Record 29 of Set 8 | astoria
# Processing Record 30 of Set 8 | san juan de miraflores
# Processing Record 31 of Set 8 | aligudarz
# Processing Record 32 of Set 8 | kimbe
# Processing Record 33 of Set 8 | salto del guaira
# Processing Record 34 of Set 8 | ogoja
# Processing Record 35 of Set 8 | guapiacu
# Processing Record 36 of Set 8 | fort bragg
# Processing Record 37 of Set 8 | cuatro cienegas de carranza
# Processing Record 38 of Set 8 | queensdale
# Processing Record 39 of Set 8 | novyy urgal
# Processing Record 40 of Set 8 | 'alaqahdari dishu
# Processing Record 41 of Set 8 | tabou
# Processing Record 42 of Set 8 | limassol
# Processing Record 43 of Set 8 | alotau
# City not found. Skipping...
# Processing Record 44 of Set 8 | el rosario
# Processing Record 45 of Set 8 | margate
# Processing Record 46 of Set 8 | san pedro pochutla
# Processing Record 47 of Set 8 | fort mcmurray
# Processing Record 48 of Set 8 | sittwe
# Processing Record 49 of Set 8 | ploneour-lanvern
# Processing Record 0 of Set 9 | kavarna
# Processing Record 1 of Set 9 | kudat
# Processing Record 2 of Set 9 | chateau-du-loir
# Processing Record 3 of Set 9 | uturoa
# Processing Record 4 of Set 9 | poltavka
# Processing Record 5 of Set 9 | mahina
# Processing Record 6 of Set 9 | patnanungan
# Processing Record 7 of Set 9 | tirebolu
# Processing Record 8 of Set 9 | singaraja
# Processing Record 9 of Set 9 | fada
# Processing Record 10 of Set 9 | tsiolkovskiy
# City not found. Skipping...
# Processing Record 11 of Set 9 | puerto santa
# Processing Record 12 of Set 9 | kone
# Processing Record 13 of Set 9 | tangalle
# Processing Record 14 of Set 9 | ad dabbah
# Processing Record 15 of Set 9 | shimonoseki
# Processing Record 16 of Set 9 | dudinka
# Processing Record 17 of Set 9 | ocean pointe
# City not found. Skipping...
# Processing Record 18 of Set 9 | ribeira brava
# Processing Record 19 of Set 9 | boizenburg
# Processing Record 20 of Set 9 | akkol'
# Processing Record 21 of Set 9 | bamboo flat
# Processing Record 22 of Set 9 | kingston
# Processing Record 23 of Set 9 | amga
# Processing Record 24 of Set 9 | midvagur
# Processing Record 25 of Set 9 | udachny
# Processing Record 26 of Set 9 | nemuro
# Processing Record 27 of Set 9 | keita
# Processing Record 28 of Set 9 | ritchie
# Processing Record 29 of Set 9 | robertsport
# Processing Record 30 of Set 9 | floro
# Processing Record 31 of Set 9 | nabire
# Processing Record 32 of Set 9 | aracati
# Processing Record 33 of Set 9 | saint-philippe
# Processing Record 34 of Set 9 | dunedin
# Processing Record 35 of Set 9 | ashchysay
# Processing Record 36 of Set 9 | al kharijah
# Processing Record 37 of Set 9 | labytnangi
# Processing Record 38 of Set 9 | barclayville
# Processing Record 39 of Set 9 | pimenta bueno
# Processing Record 40 of Set 9 | puerto baquerizo moreno
# Processing Record 41 of Set 9 | prineville
# Processing Record 42 of Set 9 | zeya
# Processing Record 43 of Set 9 | guiuan
# Processing Record 44 of Set 9 | banjarmasin
# Processing Record 45 of Set 9 | vila franca do campo
# Processing Record 46 of Set 9 | musoma
# Processing Record 47 of Set 9 | vingt cinq
# City not found. Skipping...
# Processing Record 48 of Set 9 | katima mulilo
# Processing Record 49 of Set 9 | karaton
# Processing Record 0 of Set 10 | port alfred
# Processing Record 1 of Set 10 | rongelap
# Processing Record 2 of Set 10 | taroa
# Processing Record 3 of Set 10 | coronel suarez
# Processing Record 4 of Set 10 | gweru
# Processing Record 5 of Set 10 | kashkhatau
# Processing Record 6 of Set 10 | san felipe
# Processing Record 7 of Set 10 | voi
# Processing Record 8 of Set 10 | guerrero negro
# Processing Record 9 of Set 10 | spring creek
# Processing Record 10 of Set 10 | klerksdorp
# Processing Record 11 of Set 10 | behat
# Processing Record 12 of Set 10 | wanning
# Processing Record 13 of Set 10 | ayr
# Processing Record 14 of Set 10 | conception bay south
# Processing Record 15 of Set 10 | baoding
# Processing Record 16 of Set 10 | kattivakkam
# Processing Record 17 of Set 10 | jaicos
# Processing Record 18 of Set 10 | mugia
# Processing Record 19 of Set 10 | muriti
# Processing Record 20 of Set 10 | mancio lima
# Processing Record 21 of Set 10 | sinop
# Processing Record 22 of Set 10 | geneina
# Processing Record 23 of Set 10 | sangola
# Processing Record 24 of Set 10 | wynyard
# Processing Record 25 of Set 10 | akrehamn
# Processing Record 26 of Set 10 | jiaozhou
# Processing Record 27 of Set 10 | praia da vitoria
# Processing Record 28 of Set 10 | nueva palestina
# Processing Record 29 of Set 10 | sao felix do xingu
# Processing Record 30 of Set 10 | amarante do maranhao
# Processing Record 31 of Set 10 | yemva
# Processing Record 32 of Set 10 | inarajan village
# Processing Record 33 of Set 10 | alice springs
# Processing Record 34 of Set 10 | kavaratti
# Processing Record 35 of Set 10 | kharan
# Processing Record 36 of Set 10 | north ward
# Processing Record 37 of Set 10 | yuzhno-kurilsk
# Processing Record 38 of Set 10 | lodwar
# Processing Record 39 of Set 10 | zhosaly
# Processing Record 40 of Set 10 | oroqen zizhiqi
# Processing Record 41 of Set 10 | huron
# Processing Record 42 of Set 10 | manokwari
# Processing Record 43 of Set 10 | el hadjira
# Processing Record 44 of Set 10 | lesozavodsk
# Processing Record 45 of Set 10 | hinton
# Processing Record 46 of Set 10 | port glaud
# City not found. Skipping...
# Processing Record 47 of Set 10 | andergrove
# Processing Record 48 of Set 10 | metahara
# Processing Record 49 of Set 10 | al burayqah
# Processing Record 0 of Set 11 | sampit
# Processing Record 1 of Set 11 | gadzhiyevo
# Processing Record 2 of Set 11 | selfoss
# Processing Record 3 of Set 11 | maloye ganyushkino
# Processing Record 4 of Set 11 | mazagao
# Processing Record 5 of Set 11 | barah
# Processing Record 6 of Set 11 | port saint john's
# Processing Record 7 of Set 11 | ciudad lazaro cardenas
# Processing Record 8 of Set 11 | miranda
# Processing Record 9 of Set 11 | savannakhet
# Processing Record 10 of Set 11 | romanovskaya
# Processing Record 11 of Set 11 | ponta delgada
# Processing Record 12 of Set 11 | birobidzhan
# Processing Record 13 of Set 11 | howrah
# Processing Record 14 of Set 11 | zuenoula
# Processing Record 15 of Set 11 | butembo
# Processing Record 16 of Set 11 | tymovskoye
# Processing Record 17 of Set 11 | yamazakicho-nakabirose
# Processing Record 18 of Set 11 | anabar
# City not found. Skipping...
# Processing Record 19 of Set 11 | magadan
# Processing Record 20 of Set 11 | parham
# Processing Record 21 of Set 11 | bayan nur
# City not found. Skipping...
# Processing Record 22 of Set 11 | santa marta
# Processing Record 23 of Set 11 | hasaki
# Processing Record 24 of Set 11 | anyama
# Processing Record 25 of Set 11 | quellon
# Processing Record 26 of Set 11 | manta
# Processing Record 27 of Set 11 | puerto lempira
# Processing Record 28 of Set 11 | capinota
# Processing Record 29 of Set 11 | jayapura
# Processing Record 30 of Set 11 | barcelos
# Processing Record 31 of Set 11 | kasimov
# Processing Record 32 of Set 11 | lorengau
# Processing Record 33 of Set 11 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 34 of Set 11 | nadym
# Processing Record 35 of Set 11 | natal
# Processing Record 36 of Set 11 | necochea
# Processing Record 37 of Set 11 | umba
# Processing Record 38 of Set 11 | peterhead
# Processing Record 39 of Set 11 | saint-francois
# Processing Record 40 of Set 11 | bruggen
# Processing Record 41 of Set 11 | kayenta
# Processing Record 42 of Set 11 | lisakovsk
# Processing Record 43 of Set 11 | tranovaho
# City not found. Skipping...
# Processing Record 44 of Set 11 | punta del este
# Processing Record 45 of Set 11 | frontera
# Processing Record 46 of Set 11 | aketi
# Processing Record 47 of Set 11 | deming
# Processing Record 48 of Set 11 | saudarkrokur
# Processing Record 49 of Set 11 | shitanjing
# Processing Record 0 of Set 12 | panorama
# Processing Record 1 of Set 12 | gali
# Processing Record 2 of Set 12 | krasnokamensk
# Processing Record 3 of Set 12 | bikenibeu village
# Processing Record 4 of Set 12 | bang saphan
# Processing Record 5 of Set 12 | gubkinskiy
# Processing Record 6 of Set 12 | bengkulu
# Processing Record 7 of Set 12 | kuvshinovo
# Processing Record 8 of Set 12 | arraial do cabo
# Processing Record 9 of Set 12 | chipinge
# Processing Record 10 of Set 12 | sengiley
# Processing Record 11 of Set 12 | purpe
# Processing Record 12 of Set 12 | saksaul'skiy
# City not found. Skipping...
# Processing Record 13 of Set 12 | filingue
# Processing Record 14 of Set 12 | pavullo nel frignano
# Processing Record 15 of Set 12 | hotan
# Processing Record 16 of Set 12 | sarmiento
# Processing Record 17 of Set 12 | mejit
# Processing Record 18 of Set 12 | yelabuga
# Processing Record 19 of Set 12 | arafat
# Processing Record 20 of Set 12 | boju
# Processing Record 21 of Set 12 | yangor
# City not found. Skipping...
# Processing Record 22 of Set 12 | chubek
# Processing Record 23 of Set 12 | mota del cuervo
# Processing Record 24 of Set 12 | isle of lewis
# City not found. Skipping...
# Processing Record 25 of Set 12 | sola
# Processing Record 26 of Set 12 | kralendijk
# Processing Record 27 of Set 12 | zalesovo
# Processing Record 28 of Set 12 | penzance
# Processing Record 29 of Set 12 | kyzyl-mazhalyk
# Processing Record 30 of Set 12 | tanki leendert
# City not found. Skipping...
# Processing Record 31 of Set 12 | quepos
# Processing Record 32 of Set 12 | puerto carreno
# Processing Record 33 of Set 12 | kushk
# Processing Record 34 of Set 12 | toga village
# City not found. Skipping...
# Processing Record 35 of Set 12 | tadine
# Processing Record 36 of Set 12 | sonsorol village
# City not found. Skipping...
# Processing Record 37 of Set 12 | flin flon
# Processing Record 38 of Set 12 | westport
# Processing Record 39 of Set 12 | pontianak
# Processing Record 40 of Set 12 | sao lourenco do oeste
# Processing Record 41 of Set 12 | malango
# Processing Record 42 of Set 12 | hadibu
# Processing Record 43 of Set 12 | zouerate
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
# Show Record Count
city_data_df.count()
# Out:
# City          565
# Lat           565
# Lng           565
# Max Temp      565
# Humidity      565
# Cloudiness    565
# Wind Speed    565
# Country       565
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#         City      Lat      Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    aasiaat  68.7098 -52.8699     30.54        80          56        7.36
# 1  jamestown  42.0970 -79.2353     71.02        91         100        8.05
# 2      ocher  57.8904  54.7202     50.81        89         100        8.39
# 3      reyes -14.3167 -67.3833     63.66        69         100        4.32
# 4   atherton  53.5237  -2.4935     57.74        78         100        3.00
#
#   Country
# 0      GL
# 1      US
# 2      RU
# 3      BO
# 4      GB

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#               City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          aasiaat  68.7098 -52.8699     30.54        80          56
# 1        jamestown  42.0970 -79.2353     71.02        91         100
# 2            ocher  57.8904  54.7202     50.81        89         100
# 3            reyes -14.3167 -67.3833     63.66        69         100
# 4         atherton  53.5237  -2.4935     57.74        78         100
#
#          Wind Speed Country
# City_ID
# 0              7.36      GL
# 1              8.05      US
# 2              8.39      RU
# 3              4.32      BO
# 4              3.00      GB

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"],city_data_df["Max Temp"],facecolors="green")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Temperature (°C)")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"],city_data_df["Humidity"],facecolors="red")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"],city_data_df["Cloudiness"],facecolors="blue")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"],city_data_df["Wind Speed"],facecolors="yellow")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (kmph)")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_regression_plots(x_values, y_values, title, text_coordinates):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, 'r-')
    plt.annotate(line_eq, text_coordinates, fontsize=15, color='red')
    plt.xlabel('Latitude')
    plt.ylabel(title)
    print(f"The r-squared value is: {rvalue**2}")
    print(f"The r value is: {rvalue}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[pd.to_numeric(city_data_df["Lat"]).astype(float) > 0, :]

# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          aasiaat  68.7098 -52.8699     30.54        80          56
# 1        jamestown  42.0970 -79.2353     71.02        91         100
# 2            ocher  57.8904  54.7202     50.81        89         100
# 4         atherton  53.5237  -2.4935     57.74        78         100
# 5           dakhla  23.6848 -15.9580     65.14        85         100
#
#          Wind Speed Country
# City_ID
# 0              7.36      GL
# 1              8.05      US
# 2              8.39      RU
# 4              3.00      GB
# 5             21.27      EH

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[pd.to_numeric(city_data_df["Lat"]).astype(float) < 0, :]

# Display sample data
southern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 3                 reyes -14.3167  -67.3833     63.66        69         100
# 10            papatowai -46.5619  169.4708     42.89        76          97
# 12           codrington -38.2667  141.9667     43.68        89           9
# 13       puerto natales -51.7236  -72.4875     32.45        86           0
# 14            grytviken -54.2811  -36.5092     17.53        74          91
#
#          Wind Speed Country
# City_ID
# 3              4.32      BO
# 10            24.18      NZ
# 12             7.67      AU
# 13             3.44      CL
# 14             9.73      GS

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df["Max Temp"]
linear_regression_plots(x_values, y_values, "Max Temp", (6, -10))
# Save the figure
plt.savefig("output_data/Fig5.png")
# Out:
# The r-squared value is: 0.6525095702234361
# The r value is: -0.8077806448680459

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df["Max Temp"]
linear_regression_plots(x_values, y_values, "Max Temp", (6, -10))
# Save the figure
plt.savefig("output_data/Fig6.png")
# Out:
# The r-squared value is: 0.7257604640109927
# The r value is: 0.851915761100235

# %% [markdown]
# **Discussion about the linear relationship:** After analyzing these specific plots, we can infer that temperature and latitude have a correlation. In particular, the northern hemisphere has a r-value of -0.7952768701902554 which is statistically significant. The southern hemisphere also has a high 0.8748035990044993. This shows that in the northern hemisphere, the further north a city is, the lower the maximum temperature will be. The opposite goes for the southern hemisphere, with maximum temperature showing a decrease the further south the city's location is. In general, the further a city is from the equator, the lower the maximum temperature.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df["Humidity"]
linear_regression_plots(x_values, y_values, "Humidity", (6, -10))
# Save the figure
plt.savefig("output_data/Fig7.png")
# Out:
# The r-squared value is: 0.01641348744540304
# The r value is: 0.12811513355339033

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df["Humidity"]
linear_regression_plots(x_values, y_values, "Humidity", (6, -10))
# Save the figure
plt.savefig("output_data/Fig8.png")
# Out:
# The r-squared value is: 0.00741827346421292
# The r value is: 0.08612939953472867

# %% [markdown]
# **Discussion about the linear relationship:** In this section, we discuss latitude vs humidity for the cities listed in this project. For the northern hemisphere data, we can see that the r-value is 0.12811513355339033, which is a weak correlation. For the southern hemisphere the r-value is 0.08612939953472867, which is also a weak correlation. After analyzing this data, one can infer that there is little correlation between latitude and humidity. In particular, the time of day and proximity to evaporating water (water vapor) is more indicative of a location's humidity

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df["Cloudiness"]
linear_regression_plots(x_values, y_values, "Cloudiness", (6, -10))
# Save the figure
plt.savefig("output_data/Fig9.png")
# Out:
# The r-squared value is: 0.00015688667120831935
# The r value is: 0.012525440958637718

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df["Cloudiness"]
linear_regression_plots(x_values, y_values, "Cloudiness", (6, -10))
# Save the figure
plt.savefig("output_data/Fig10.png")
# Out:
# The r-squared value is: 0.03378827206790494
# The r value is: 0.18381586457078436

# %% [markdown]
# **Discussion about the linear relationship:** In the case of cloudiness, the northern hemisphere has an r-value of 0.012525440958637718, and the southern hemisphere has an r-value of 0.18381586457078436. Both of these r-values indicate that there is very little correlation between latitude and cloudiness. This indicates that the latitude has little correlation with cloudiness. In similar fashion to the previous question, variables such as time of day/seasons, as well as proximity to water vapor is more strongly correlated to cloudiness.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df["Wind Speed"]
linear_regression_plots(x_values, y_values, "Wind Speed", (6, -10))
# Save the figure
plt.savefig("output_data/Fig11.png")
# Out:
# The r-squared value is: 0.002789290494425996
# The r value is: -0.052813733956481396

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df["Wind Speed"]
linear_regression_plots(x_values, y_values, "Wind Speed", (6, -10))
# Save the figure
plt.savefig("output_data/Fig12.png")
# Out:
# The r-squared value is: 0.07325736186960423
# The r value is: -0.2706609721951139

# %% [markdown]
# **Discussion about the linear relationship:** For the northern hemisphere, the r-value is -0.052813733956481396, whereas in the southern hemisphere, the r-value is -0.2706609721951139. Although neither of these are particularly significant when it comes to correlation between wind speed and latitude, we can see that in the southern hemisphere there is a larger correlation, however this is very slight. Geographic features (or lack thereof) tend to have a more significant correlation to wind speed.
